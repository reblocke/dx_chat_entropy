# %%
# %mamba install scienceplots -c conda-forge -y
# Out:
# warning  libmamba 'repo.anaconda.com', a commercial channel hosted by Anaconda.com, is used.
#
# warning  libmamba Please make sure you understand Anaconda Terms of Services.
#
# warning  libmamba See: https://legal.anaconda.com/policies/en/
# [+] 0.0s
# [+] 0.0s
# [+] 0.1s
# conda-forge/noarch    ━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# conda-forge/osx-arm64 ━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# pkgs/main/noarch      ━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# pkgs/main/osx-arm64   ━━━━━━━━╸━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# pkgs/r/noarch         ━━━━━━━━╸━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0spkgs/main/noarch                                    ??.?MB @  ??.?MB/s  0.1s
# [+] 0.2s
# conda-forge/noarch    ━━━━━━━━╸━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# conda-forge/osx-arm64 ━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/main/osx-arm64   ━━━━━━━━━╸━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/r/noarch         ━━━━━━━━━╸━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 0.3s
# conda-forge/noarch    ━━━━━━━━━━━━━━━━━━━━━━ 110.2kB /  21.6MB @ 460.9kB/s  0.2s
# conda-forge/osx-arm64 ━━━━━━━━━━━━━━━━━━━━━━  30.1kB /  16.9MB @ 125.6kB/s  0.2s
# pkgs/main/osx-arm64   ━━━━━━━━━━━╸━━━━━━━━━━   2.3MB /   4.2MB @   9.0MB/s  0.2spkgs/main/osx-arm64                                  4.2MB @  10.9MB/s  0.3s
# [+] 0.4s
# conda-forge/noarch    ╸━━━━━━━━━━━━━━━━━━━━━   1.7MB /  21.6MB @   4.3MB/s  0.3s
# conda-forge/osx-arm64 ╸━━━━━━━━━━━━━━━━━━━━━   1.3MB /  16.9MB @   3.4MB/s  0.3s[+] 0.5s
# conda-forge/noarch    ━━╸━━━━━━━━━━━━━━━━━━━   3.5MB /  21.6MB @   7.0MB/s  0.4s
# conda-forge/osx-arm64 ━━╸━━━━━━━━━━━━━━━━━━━   2.6MB /  16.9MB @   5.4MB/s  0.4s[+] 0.6s
# conda-forge/noarch    ━━━━━╸━━━━━━━━━━━━━━━━   6.1MB /  21.6MB @  10.2MB/s  0.5s
# conda-forge/osx-arm64 ━━━━━━╸━━━━━━━━━━━━━━━   5.6MB /  16.9MB @   9.3MB/s  0.5s[+] 0.7s
# conda-forge/noarch    ━━━━━━╸━━━━━━━━━━━━━━━   7.5MB /  21.6MB @  11.5MB/s  0.6s
# conda-forge/osx-arm64 ━━━━━━━━╸━━━━━━━━━━━━━   7.0MB /  16.9MB @  10.7MB/s  0.6s[+] 0.8s
# conda-forge/noarch    ━━━━━━━━╸━━━━━━━━━━━━━   9.8MB /  21.6MB @  13.0MB/s  0.7s
# conda-forge/osx-arm64 ━━━━━━━━━━━╸━━━━━━━━━━   9.4MB /  16.9MB @  12.4MB/s  0.7s[+] 0.9s
# conda-forge/noarch    ━━━━━━━━━━━╸━━━━━━━━━━  12.3MB /  21.6MB @  14.1MB/s  0.8s
# conda-forge/osx-arm64 ━━━━━━━━━━━━━━╸━━━━━━━  11.9MB /  16.9MB @  13.4MB/s  0.8s[+] 1.0s
# conda-forge/noarch    ━━━━━━━━━━━━━╸━━━━━━━━  14.4MB /  21.6MB @  14.7MB/s  0.9s
# conda-forge/osx-arm64 ━━━━━━━━━━━━━━━╸━━━━━━  13.2MB /  16.9MB @  13.8MB/s  0.9sconda-forge/osx-arm64                               16.9MB @  15.0MB/s  1.0s
# [+] 1.1s
# conda-forge/noarch ━━━━━━━━━━━━━━━━━━╸━━━━━━  17.3MB /  21.6MB @  15.9MB/s  1.0sconda-forge/noarch                                  21.6MB @  17.5MB/s  1.1s
#
# Pinned packages:
#
#   - python=3.11
#
#
# Transaction
#
#   Prefix: /Users/blocke/anaconda3/envs/llm_py311
#
#   Updating specs:
#
#    - scienceplots
#
#
#   Package            Version  Build            Channel           Size
# ───────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────
#
#   + brotli             1.1.0  h5505292_3       conda-forge     Cached
#   + brotli-bin         1.1.0  h5505292_3       conda-forge     Cached
#   + contourpy          1.3.3  py311h57a9ea7_1  conda-forge      257kB
#   + cycler            0.12.1  pyhd8ed1ab_1     conda-forge     Cached
#   + fonttools         4.59.0  py311h2fe624c_0  conda-forge        3MB
#   + freetype          2.13.3  hce30654_1       conda-forge     Cached
#   + kiwisolver         1.4.9  py311h63e5c0c_0  conda-forge       66kB
#   + lcms2               2.17  h7eeda09_0       conda-forge     Cached
#   + lerc               4.0.0  hd64df32_1       conda-forge     Cached
#   + libbrotlicommon    1.1.0  h5505292_3       conda-forge     Cached
#   + libbrotlidec       1.1.0  h5505292_3       conda-forge     Cached
#   + libbrotlienc       1.1.0  h5505292_3       conda-forge     Cached
#   + libdeflate          1.24  h5773f1b_0       conda-forge     Cached
#   + libfreetype       2.13.3  hce30654_1       conda-forge     Cached
#   + libfreetype6      2.13.3  h1d14073_1       conda-forge     Cached
#   + libjpeg-turbo      3.1.0  h5505292_0       conda-forge     Cached
#   + libpng            1.6.50  h280e0eb_1       conda-forge     Cached
#   + libtiff            4.7.0  h025e3ab_6       conda-forge      372kB
#   + libwebp-base       1.6.0  h07db88b_0       conda-forge     Cached
#   + libxcb            1.17.0  hdb1d25a_0       conda-forge     Cached
#   + matplotlib-base   3.10.5  py311h66dac5a_0  conda-forge        8MB
#   + munkres            1.1.4  pyhd8ed1ab_1     conda-forge     Cached
#   + openjpeg           2.5.3  h889cd5d_1       conda-forge      320kB
#   + pillow            11.3.0  py311hb9ba9e9_0  conda-forge       42MB
#   + pthread-stubs        0.4  hd74edd7_1002    conda-forge     Cached
#   + pyparsing          3.2.3  pyhe01879c_2     conda-forge     Cached
#   + qhull             2020.2  h420ef59_5       conda-forge     Cached
#   + scienceplots       2.1.1  pyhd8ed1ab_1     conda-forge       19kB
#   + unicodedata2      16.0.0  py311h917b07b_0  conda-forge      411kB
#   + xorg-libxau       1.0.12  h5505292_0       conda-forge     Cached
#   + xorg-libxdmcp      1.1.5  hd74edd7_0       conda-forge     Cached
#   + zstd               1.5.7  h6491c7d_2       conda-forge     Cached
#
#   Summary:
#
#   Install: 32 packages
#
#   Total download: 55MB
#
# ───────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# [+] 0.0s
# Downloading      ╸━━━━━━━━━━━━━━━━━━━━━━   0.0 B                            0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 0.1s
# Downloading  (5) ━━━━━━━━━━━━━━━━━━━━━━━ 267.7kB fonttools                  0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0sunicodedata2                                       411.2kB @   1.3MB/s  0.1s
# libtiff                                            372.1kB @ 144.1kB/s  0.1s
# openjpeg                                           320.2kB @  ??.?MB/s  0.1s
# [+] 0.2s
# Downloading  (5) ━╸━━━━━━━━━━━━━━━━━━━━━   5.6MB fonttools                  0.1s
# Extracting   (1) ━━━━╸━━╸━━━━━━━━━━━━━━━       2 openjpeg                   0.0scontourpy                                          257.5kB @  ??.?MB/s  0.1s
# kiwisolver                                          66.1kB @  ??.?MB/s  0.1s
# [+] 0.3s
# Downloading  (4) ━━╸━━━━━━━━━━━━━━━━━━━━   9.2MB fonttools                  0.2s
# Extracting   (1) ━━━━━━━━━╸━━╸━━━━━━━━━━       4 kiwisolver                 0.1sscienceplots                                        18.6kB @  ??.?MB/s  0.1s
# [+] 0.4s
# Downloading  (3) ━━━━━━╸━━━━━━━━━━━━━━━━  16.9MB fonttools                  0.3s
# Extracting       ━━━━━━━━━━━━━━╸━━━━━━━━       6                            0.2sfonttools                                            2.8MB @   6.0MB/s  0.4s
# [+] 0.5s
# Downloading  (2) ━━━━━━━━━╸━━━━━━━━━━━━━  24.5MB matplotlib-base            0.4s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━╸━━━━━       6 fonttools                  0.2s[+] 0.6s
# Downloading  (2) ━━━━━━━━━━━━╸━━━━━━━━━━  32.2MB matplotlib-base            0.5s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━╸━━━━━       6 fonttools                  0.3smatplotlib-base                                      8.2MB @  11.8MB/s  0.6s
# [+] 0.7s
# Downloading  (1) ━━━━━━━━━━━━━━━╸━━━━━━━  39.7MB pillow                     0.6s
# Extracting   (1) ━━━━━━━━━━━━━━━━╸━━━╸━━       7 matplotlib-base            0.4s[+] 0.8s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━╸━━━━  45.6MB pillow                     0.7s
# Extracting   (1) ━━━━━━━━━━━━━━━━╸━━━╸━━       7 matplotlib-base            0.5s[+] 0.9s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━╸━━  51.1MB pillow                     0.8s
# Extracting   (1) ━━━━━━━━━━━━━━━━╸━━━╸━━       7 matplotlib-base            0.6spillow                                              42.0MB @  45.2MB/s  0.9s
# [+] 1.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  54.5MB                            0.9s
# Extracting   (2) ━━━━━━━━━━━━━━━━╸━━━━━━       7 matplotlib-base            0.7s[+] 1.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  54.5MB                            0.9s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━━━       8 pillow                     0.8s[+] 1.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  54.5MB                            0.9s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━━━       8 pillow                     0.9s[+] 1.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  54.5MB                            0.9s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━━━       8 pillow                     1.0s[+] 1.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  54.5MB                            0.9s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━━━       8 pillow                     1.1sLinking cycler-0.12.1-pyhd8ed1ab_1
# warning  libmamba [cycler-0.12.1-pyhd8ed1ab_1] The following files were already present in the environment:
#     - lib/python3.11/site-packages/cycler-0.12.1.dist-info/INSTALLER
#     - lib/python3.11/site-packages/cycler-0.12.1.dist-info/LICENSE
#     - lib/python3.11/site-packages/cycler-0.12.1.dist-info/METADATA
#     - lib/python3.11/site-packages/cycler-0.12.1.dist-info/RECORD
#     - lib/python3.11/site-packages/cycler-0.12.1.dist-info/WHEEL
#     - lib/python3.11/site-packages/cycler-0.12.1.dist-info/top_level.txt
#     - lib/python3.11/site-packages/cycler/__init__.py
#     - lib/python3.11/site-packages/cycler/py.typed
# Linking pyparsing-3.2.3-pyhe01879c_2
# warning  libmamba [pyparsing-3.2.3-pyhe01879c_2] The following files were already present in the environment:
#     - lib/python3.11/site-packages/pyparsing/__init__.py
#     - lib/python3.11/site-packages/pyparsing/actions.py
#     - lib/python3.11/site-packages/pyparsing/common.py
#     - lib/python3.11/site-packages/pyparsing/core.py
#     - lib/python3.11/site-packages/pyparsing/diagram/__init__.py
#     - lib/python3.11/site-packages/pyparsing/exceptions.py
#     - lib/python3.11/site-packages/pyparsing/helpers.py
#     - lib/python3.11/site-packages/pyparsing/py.typed
#     - lib/python3.11/site-packages/pyparsing/results.py
#     - lib/python3.11/site-packages/pyparsing/testing.py
#     - lib/python3.11/site-packages/pyparsing/tools/__init__.py
#     - lib/python3.11/site-packages/pyparsing/tools/cvt_pyparsing_pep8_names.py
#     - lib/python3.11/site-packages/pyparsing/unicode.py
#     - lib/python3.11/site-packages/pyparsing/util.py
#     - lib/python3.11/site-packages/pyparsing-3.2.3.dist-info/INSTALLER
#     - lib/python3.11/site-packages/pyparsing-3.2.3.dist-info/METADATA
#     - lib/python3.11/site-packages/pyparsing-3.2.3.dist-info/RECORD
#     - lib/python3.11/site-packages/pyparsing-3.2.3.dist-info/WHEEL
# Linking munkres-1.1.4-pyhd8ed1ab_1
# Linking contourpy-1.3.3-py311h57a9ea7_1
# warning  libmamba [contourpy-1.3.3-py311h57a9ea7_1] The following files were already present in the environment:
#     - lib/python3.11/site-packages/contourpy-1.3.3.dist-info/INSTALLER
#     - lib/python3.11/site-packages/contourpy-1.3.3.dist-info/LICENSE
#     - lib/python3.11/site-packages/contourpy-1.3.3.dist-info/METADATA
#     - lib/python3.11/site-packages/contourpy-1.3.3.dist-info/RECORD
#     - lib/python3.11/site-packages/contourpy-1.3.3.dist-info/WHEEL
#     - lib/python3.11/site-packages/contourpy/__init__.py
#     - lib/python3.11/site-packages/contourpy/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/__pycache__/_version.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/__pycache__/array.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/__pycache__/chunk.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/__pycache__/convert.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/__pycache__/dechunk.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/__pycache__/enum_util.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/__pycache__/typecheck.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/__pycache__/types.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/_contourpy.cpython-311-darwin.so
#     - lib/python3.11/site-packages/contourpy/_contourpy.pyi
#     - lib/python3.11/site-packages/contourpy/_version.py
#     - lib/python3.11/site-packages/contourpy/array.py
#     - lib/python3.11/site-packages/contourpy/chunk.py
#     - lib/python3.11/site-packages/contourpy/convert.py
#     - lib/python3.11/site-packages/contourpy/dechunk.py
#     - lib/python3.11/site-packages/contourpy/enum_util.py
#     - lib/python3.11/site-packages/contourpy/py.typed
#     - lib/python3.11/site-packages/contourpy/typecheck.py
#     - lib/python3.11/site-packages/contourpy/types.py
#     - lib/python3.11/site-packages/contourpy/util/__init__.py
#     - lib/python3.11/site-packages/contourpy/util/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/util/__pycache__/_build_config.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/util/__pycache__/bokeh_renderer.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/util/__pycache__/bokeh_util.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/util/__pycache__/data.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/util/__pycache__/mpl_renderer.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/util/__pycache__/mpl_util.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/util/__pycache__/renderer.cpython-311.pyc
#     - lib/python3.11/site-packages/contourpy/util/_build_config.py
#     - lib/python3.11/site-packages/contourpy/util/bokeh_renderer.py
#     - lib/python3.11/site-packages/contourpy/util/bokeh_util.py
#     - lib/python3.11/site-packages/contourpy/util/data.py
#     - lib/python3.11/site-packages/contourpy/util/mpl_renderer.py
#     - lib/python3.11/site-packages/contourpy/util/mpl_util.py
#     - lib/python3.11/site-packages/contourpy/util/renderer.py
# Linking kiwisolver-1.4.9-py311h63e5c0c_0
# warning  libmamba [kiwisolver-1.4.9-py311h63e5c0c_0] The following files were already present in the environment:
#     - lib/python3.11/site-packages/kiwisolver/__init__.py
#     - lib/python3.11/site-packages/kiwisolver/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/kiwisolver/__pycache__/exceptions.cpython-311.pyc
#     - lib/python3.11/site-packages/kiwisolver/_cext.cpython-311-darwin.so
#     - lib/python3.11/site-packages/kiwisolver/_cext.pyi
#     - lib/python3.11/site-packages/kiwisolver/exceptions.py
#     - lib/python3.11/site-packages/kiwisolver/py.typed
# Linking libjpeg-turbo-3.1.0-h5505292_0
# Linking qhull-2020.2-h420ef59_5
# Linking pthread-stubs-0.4-hd74edd7_1002
# Linking xorg-libxau-1.0.12-h5505292_0
# Linking xorg-libxdmcp-1.1.5-hd74edd7_0
# Linking libpng-1.6.50-h280e0eb_1
# Linking libdeflate-1.24-h5773f1b_0
# Linking libwebp-base-1.6.0-h07db88b_0
# Linking libbrotlicommon-1.1.0-h5505292_3
# Linking unicodedata2-16.0.0-py311h917b07b_0
# Linking lerc-4.0.0-hd64df32_1
# Linking zstd-1.5.7-h6491c7d_2
# Linking libxcb-1.17.0-hdb1d25a_0
# Linking libfreetype6-2.13.3-h1d14073_1
# Linking libbrotlienc-1.1.0-h5505292_3
# Linking libbrotlidec-1.1.0-h5505292_3
# Linking libtiff-4.7.0-h025e3ab_6
# Linking libfreetype-2.13.3-hce30654_1
# Linking brotli-bin-1.1.0-h5505292_3
# Linking openjpeg-2.5.3-h889cd5d_1
# Linking lcms2-2.17-h7eeda09_0
# Linking freetype-2.13.3-hce30654_1
# Linking brotli-1.1.0-h5505292_3
# Linking pillow-11.3.0-py311hb9ba9e9_0
# warning  libmamba [pillow-11.3.0-py311hb9ba9e9_0] The following files were already present in the environment:
#     - lib/python3.11/site-packages/PIL/AvifImagePlugin.py
#     - lib/python3.11/site-packages/PIL/BdfFontFile.py
#     - lib/python3.11/site-packages/PIL/BlpImagePlugin.py
#     - lib/python3.11/site-packages/PIL/BmpImagePlugin.py
#     - lib/python3.11/site-packages/PIL/BufrStubImagePlugin.py
#     - lib/python3.11/site-packages/PIL/ContainerIO.py
#     - lib/python3.11/site-packages/PIL/CurImagePlugin.py
#     - lib/python3.11/site-packages/PIL/DcxImagePlugin.py
#     - lib/python3.11/site-packages/PIL/DdsImagePlugin.py
#     - lib/python3.11/site-packages/PIL/EpsImagePlugin.py
#     - lib/python3.11/site-packages/PIL/ExifTags.py
#     - lib/python3.11/site-packages/PIL/FitsImagePlugin.py
#     - lib/python3.11/site-packages/PIL/FliImagePlugin.py
#     - lib/python3.11/site-packages/PIL/FontFile.py
#     - lib/python3.11/site-packages/PIL/FpxImagePlugin.py
#     - lib/python3.11/site-packages/PIL/FtexImagePlugin.py
#     - lib/python3.11/site-packages/PIL/GbrImagePlugin.py
#     - lib/python3.11/site-packages/PIL/GdImageFile.py
#     - lib/python3.11/site-packages/PIL/GifImagePlugin.py
#     - lib/python3.11/site-packages/PIL/GimpGradientFile.py
#     - lib/python3.11/site-packages/PIL/GimpPaletteFile.py
#     - lib/python3.11/site-packages/PIL/GribStubImagePlugin.py
#     - lib/python3.11/site-packages/PIL/Hdf5StubImagePlugin.py
#     - lib/python3.11/site-packages/PIL/IcnsImagePlugin.py
#     - lib/python3.11/site-packages/PIL/IcoImagePlugin.py
#     - lib/python3.11/site-packages/PIL/ImImagePlugin.py
#     - lib/python3.11/site-packages/PIL/Image.py
#     - lib/python3.11/site-packages/PIL/ImageChops.py
#     - lib/python3.11/site-packages/PIL/ImageCms.py
#     - lib/python3.11/site-packages/PIL/ImageColor.py
#     - lib/python3.11/site-packages/PIL/ImageDraw.py
#     - lib/python3.11/site-packages/PIL/ImageDraw2.py
#     - lib/python3.11/site-packages/PIL/ImageEnhance.py
#     - lib/python3.11/site-packages/PIL/ImageFile.py
#     - lib/python3.11/site-packages/PIL/ImageFilter.py
#     - lib/python3.11/site-packages/PIL/ImageFont.py
#     - lib/python3.11/site-packages/PIL/ImageGrab.py
#     - lib/python3.11/site-packages/PIL/ImageMath.py
#     - lib/python3.11/site-packages/PIL/ImageMode.py
#     - lib/python3.11/site-packages/PIL/ImageMorph.py
#     - lib/python3.11/site-packages/PIL/ImageOps.py
#     - lib/python3.11/site-packages/PIL/ImagePalette.py
#     - lib/python3.11/site-packages/PIL/ImagePath.py
#     - lib/python3.11/site-packages/PIL/ImageQt.py
#     - lib/python3.11/site-packages/PIL/ImageSequence.py
#     - lib/python3.11/site-packages/PIL/ImageShow.py
#     - lib/python3.11/site-packages/PIL/ImageStat.py
#     - lib/python3.11/site-packages/PIL/ImageTk.py
#     - lib/python3.11/site-packages/PIL/ImageTransform.py
#     - lib/python3.11/site-packages/PIL/ImageWin.py
#     - lib/python3.11/site-packages/PIL/ImtImagePlugin.py
#     - lib/python3.11/site-packages/PIL/IptcImagePlugin.py
#     - lib/python3.11/site-packages/PIL/Jpeg2KImagePlugin.py
#     - lib/python3.11/site-packages/PIL/JpegImagePlugin.py
#     - lib/python3.11/site-packages/PIL/JpegPresets.py
#     - lib/python3.11/site-packages/PIL/McIdasImagePlugin.py
#     - lib/python3.11/site-packages/PIL/MicImagePlugin.py
#     - lib/python3.11/site-packages/PIL/MpegImagePlugin.py
#     - lib/python3.11/site-packages/PIL/MpoImagePlugin.py
#     - lib/python3.11/site-packages/PIL/MspImagePlugin.py
#     - lib/python3.11/site-packages/PIL/PSDraw.py
#     - lib/python3.11/site-packages/PIL/PaletteFile.py
#     - lib/python3.11/site-packages/PIL/PalmImagePlugin.py
#     - lib/python3.11/site-packages/PIL/PcdImagePlugin.py
#     - lib/python3.11/site-packages/PIL/PcfFontFile.py
#     - lib/python3.11/site-packages/PIL/PcxImagePlugin.py
#     - lib/python3.11/site-packages/PIL/PdfImagePlugin.py
#     - lib/python3.11/site-packages/PIL/PdfParser.py
#     - lib/python3.11/site-packages/PIL/PixarImagePlugin.py
#     - lib/python3.11/site-packages/PIL/PngImagePlugin.py
#     - lib/python3.11/site-packages/PIL/PpmImagePlugin.py
#     - lib/python3.11/site-packages/PIL/PsdImagePlugin.py
#     - lib/python3.11/site-packages/PIL/QoiImagePlugin.py
#     - lib/python3.11/site-packages/PIL/SgiImagePlugin.py
#     - lib/python3.11/site-packages/PIL/SpiderImagePlugin.py
#     - lib/python3.11/site-packages/PIL/SunImagePlugin.py
#     - lib/python3.11/site-packages/PIL/TarIO.py
#     - lib/python3.11/site-packages/PIL/TgaImagePlugin.py
#     - lib/python3.11/site-packages/PIL/TiffImagePlugin.py
#     - lib/python3.11/site-packages/PIL/TiffTags.py
#     - lib/python3.11/site-packages/PIL/WalImageFile.py
#     - lib/python3.11/site-packages/PIL/WebPImagePlugin.py
#     - lib/python3.11/site-packages/PIL/WmfImagePlugin.py
#     - lib/python3.11/site-packages/PIL/XVThumbImagePlugin.py
#     - lib/python3.11/site-packages/PIL/XbmImagePlugin.py
#     - lib/python3.11/site-packages/PIL/XpmImagePlugin.py
#     - lib/python3.11/site-packages/PIL/__init__.py
#     - lib/python3.11/site-packages/PIL/__main__.py
#     - lib/python3.11/site-packages/PIL/__pycache__/AvifImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/BdfFontFile.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/BlpImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/BmpImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/BufrStubImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ContainerIO.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/CurImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/DcxImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/DdsImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/EpsImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ExifTags.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/FitsImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/FliImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/FontFile.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/FpxImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/FtexImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/GbrImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/GdImageFile.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/GifImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/GimpGradientFile.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/GimpPaletteFile.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/GribStubImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/Hdf5StubImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/IcnsImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/IcoImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/Image.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageChops.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageCms.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageColor.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageDraw.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageDraw2.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageEnhance.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageFile.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageFilter.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageFont.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageGrab.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageMath.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageMode.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageMorph.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageOps.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImagePalette.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImagePath.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageQt.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageSequence.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageShow.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageStat.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageTk.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageTransform.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImageWin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/ImtImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/IptcImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/Jpeg2KImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/JpegImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/JpegPresets.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/McIdasImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/MicImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/MpegImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/MpoImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/MspImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/PSDraw.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/PaletteFile.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/PalmImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/PcdImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/PcfFontFile.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/PcxImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/PdfImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/PdfParser.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/PixarImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/PngImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/PpmImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/PsdImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/QoiImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/SgiImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/SpiderImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/SunImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/TarIO.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/TgaImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/TiffImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/TiffTags.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/WalImageFile.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/WebPImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/WmfImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/XVThumbImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/XbmImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/XpmImagePlugin.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/__main__.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/_binary.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/_deprecate.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/_tkinter_finder.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/_typing.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/_util.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/_version.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/features.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/__pycache__/report.cpython-311.pyc
#     - lib/python3.11/site-packages/PIL/_avif.pyi
#     - lib/python3.11/site-packages/PIL/_binary.py
#     - lib/python3.11/site-packages/PIL/_deprecate.py
#     - lib/python3.11/site-packages/PIL/_imaging.cpython-311-darwin.so
#     - lib/python3.11/site-packages/PIL/_imaging.pyi
#     - lib/python3.11/site-packages/PIL/_imagingcms.cpython-311-darwin.so
#     - lib/python3.11/site-packages/PIL/_imagingcms.pyi
#     - lib/python3.11/site-packages/PIL/_imagingft.cpython-311-darwin.so
#     - lib/python3.11/site-packages/PIL/_imagingft.pyi
#     - lib/python3.11/site-packages/PIL/_imagingmath.cpython-311-darwin.so
#     - lib/python3.11/site-packages/PIL/_imagingmath.pyi
#     - lib/python3.11/site-packages/PIL/_imagingmorph.cpython-311-darwin.so
#     - lib/python3.11/site-packages/PIL/_imagingmorph.pyi
#     - lib/python3.11/site-packages/PIL/_imagingtk.cpython-311-darwin.so
#     - lib/python3.11/site-packages/PIL/_imagingtk.pyi
#     - lib/python3.11/site-packages/PIL/_tkinter_finder.py
#     - lib/python3.11/site-packages/PIL/_typing.py
#     - lib/python3.11/site-packages/PIL/_util.py
#     - lib/python3.11/site-packages/PIL/_version.py
#     - lib/python3.11/site-packages/PIL/_webp.cpython-311-darwin.so
#     - lib/python3.11/site-packages/PIL/_webp.pyi
#     - lib/python3.11/site-packages/PIL/features.py
#     - lib/python3.11/site-packages/PIL/py.typed
#     - lib/python3.11/site-packages/PIL/report.py
#     - lib/python3.11/site-packages/pillow-11.3.0.dist-info/INSTALLER
#     - lib/python3.11/site-packages/pillow-11.3.0.dist-info/METADATA
#     - lib/python3.11/site-packages/pillow-11.3.0.dist-info/RECORD
#     - lib/python3.11/site-packages/pillow-11.3.0.dist-info/WHEEL
#     - lib/python3.11/site-packages/pillow-11.3.0.dist-info/licenses/LICENSE
#     - lib/python3.11/site-packages/pillow-11.3.0.dist-info/top_level.txt
#     - lib/python3.11/site-packages/pillow-11.3.0.dist-info/zip-safe
# Linking fonttools-4.59.0-py311h2fe624c_0
# warning  libmamba [fonttools-4.59.0-py311h2fe624c_0] The following files were already present in the environment:
#     - bin/fonttools
#     - bin/pyftmerge
#     - bin/pyftsubset
#     - bin/ttx
#     - lib/python3.11/site-packages/fontTools/__init__.py
#     - lib/python3.11/site-packages/fontTools/__main__.py
#     - lib/python3.11/site-packages/fontTools/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/__pycache__/__main__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/__pycache__/afmLib.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/__pycache__/agl.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/__pycache__/fontBuilder.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/__pycache__/help.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/__pycache__/tfmLib.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/__pycache__/ttx.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/__pycache__/unicode.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/afmLib.py
#     - lib/python3.11/site-packages/fontTools/agl.py
#     - lib/python3.11/site-packages/fontTools/cffLib/CFF2ToCFF.py
#     - lib/python3.11/site-packages/fontTools/cffLib/CFFToCFF2.py
#     - lib/python3.11/site-packages/fontTools/cffLib/__init__.py
#     - lib/python3.11/site-packages/fontTools/cffLib/__pycache__/CFF2ToCFF.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/cffLib/__pycache__/CFFToCFF2.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/cffLib/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/cffLib/__pycache__/specializer.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/cffLib/__pycache__/transforms.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/cffLib/__pycache__/width.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/cffLib/specializer.py
#     - lib/python3.11/site-packages/fontTools/cffLib/transforms.py
#     - lib/python3.11/site-packages/fontTools/cffLib/width.py
#     - lib/python3.11/site-packages/fontTools/colorLib/__init__.py
#     - lib/python3.11/site-packages/fontTools/colorLib/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/colorLib/__pycache__/builder.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/colorLib/__pycache__/errors.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/colorLib/__pycache__/geometry.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/colorLib/__pycache__/table_builder.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/colorLib/__pycache__/unbuilder.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/colorLib/builder.py
#     - lib/python3.11/site-packages/fontTools/colorLib/errors.py
#     - lib/python3.11/site-packages/fontTools/colorLib/geometry.py
#     - lib/python3.11/site-packages/fontTools/colorLib/table_builder.py
#     - lib/python3.11/site-packages/fontTools/colorLib/unbuilder.py
#     - lib/python3.11/site-packages/fontTools/config/__init__.py
#     - lib/python3.11/site-packages/fontTools/config/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/cu2qu/__init__.py
#     - lib/python3.11/site-packages/fontTools/cu2qu/__main__.py
#     - lib/python3.11/site-packages/fontTools/cu2qu/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/cu2qu/__pycache__/__main__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/cu2qu/__pycache__/benchmark.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/cu2qu/__pycache__/cli.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/cu2qu/__pycache__/cu2qu.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/cu2qu/__pycache__/errors.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/cu2qu/__pycache__/ufo.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/cu2qu/benchmark.py
#     - lib/python3.11/site-packages/fontTools/cu2qu/cli.py
#     - lib/python3.11/site-packages/fontTools/cu2qu/cu2qu.c
#     - lib/python3.11/site-packages/fontTools/cu2qu/cu2qu.cpython-311-darwin.so
#     - lib/python3.11/site-packages/fontTools/cu2qu/cu2qu.py
#     - lib/python3.11/site-packages/fontTools/cu2qu/errors.py
#     - lib/python3.11/site-packages/fontTools/cu2qu/ufo.py
#     - lib/python3.11/site-packages/fontTools/designspaceLib/__init__.py
#     - lib/python3.11/site-packages/fontTools/designspaceLib/__main__.py
#     - lib/python3.11/site-packages/fontTools/designspaceLib/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/designspaceLib/__pycache__/__main__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/designspaceLib/__pycache__/split.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/designspaceLib/__pycache__/statNames.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/designspaceLib/__pycache__/types.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/designspaceLib/split.py
#     - lib/python3.11/site-packages/fontTools/designspaceLib/statNames.py
#     - lib/python3.11/site-packages/fontTools/designspaceLib/types.py
#     - lib/python3.11/site-packages/fontTools/encodings/MacRoman.py
#     - lib/python3.11/site-packages/fontTools/encodings/StandardEncoding.py
#     - lib/python3.11/site-packages/fontTools/encodings/__init__.py
#     - lib/python3.11/site-packages/fontTools/encodings/__pycache__/MacRoman.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/encodings/__pycache__/StandardEncoding.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/encodings/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/encodings/__pycache__/codecs.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/encodings/codecs.py
#     - lib/python3.11/site-packages/fontTools/feaLib/__init__.py
#     - lib/python3.11/site-packages/fontTools/feaLib/__main__.py
#     - lib/python3.11/site-packages/fontTools/feaLib/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/feaLib/__pycache__/__main__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/feaLib/__pycache__/ast.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/feaLib/__pycache__/builder.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/feaLib/__pycache__/error.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/feaLib/__pycache__/lexer.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/feaLib/__pycache__/location.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/feaLib/__pycache__/lookupDebugInfo.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/feaLib/__pycache__/parser.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/feaLib/__pycache__/variableScalar.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/feaLib/ast.py
#     - lib/python3.11/site-packages/fontTools/feaLib/builder.py
#     - lib/python3.11/site-packages/fontTools/feaLib/error.py
#     - lib/python3.11/site-packages/fontTools/feaLib/lexer.c
#     - lib/python3.11/site-packages/fontTools/feaLib/lexer.cpython-311-darwin.so
#     - lib/python3.11/site-packages/fontTools/feaLib/lexer.py
#     - lib/python3.11/site-packages/fontTools/feaLib/location.py
#     - lib/python3.11/site-packages/fontTools/feaLib/lookupDebugInfo.py
#     - lib/python3.11/site-packages/fontTools/feaLib/parser.py
#     - lib/python3.11/site-packages/fontTools/feaLib/variableScalar.py
#     - lib/python3.11/site-packages/fontTools/fontBuilder.py
#     - lib/python3.11/site-packages/fontTools/help.py
#     - lib/python3.11/site-packages/fontTools/merge/__init__.py
#     - lib/python3.11/site-packages/fontTools/merge/__main__.py
#     - lib/python3.11/site-packages/fontTools/merge/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/merge/__pycache__/__main__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/merge/__pycache__/base.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/merge/__pycache__/cmap.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/merge/__pycache__/layout.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/merge/__pycache__/options.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/merge/__pycache__/tables.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/merge/__pycache__/unicode.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/merge/__pycache__/util.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/merge/base.py
#     - lib/python3.11/site-packages/fontTools/merge/cmap.py
#     - lib/python3.11/site-packages/fontTools/merge/layout.py
#     - lib/python3.11/site-packages/fontTools/merge/options.py
#     - lib/python3.11/site-packages/fontTools/merge/tables.py
#     - lib/python3.11/site-packages/fontTools/merge/unicode.py
#     - lib/python3.11/site-packages/fontTools/merge/util.py
#     - lib/python3.11/site-packages/fontTools/misc/__init__.py
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/arrayTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/bezierTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/classifyTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/cliTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/configTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/cython.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/dictTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/eexec.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/encodingTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/etree.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/filenames.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/fixedTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/intTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/iterTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/lazyTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/loggingTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/macCreatorType.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/macRes.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/psCharStrings.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/psLib.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/psOperators.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/py23.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/roundTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/sstruct.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/symfont.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/testTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/textTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/timeTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/transform.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/treeTools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/vector.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/visitor.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/xmlReader.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/__pycache__/xmlWriter.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/arrayTools.py
#     - lib/python3.11/site-packages/fontTools/misc/bezierTools.c
#     - lib/python3.11/site-packages/fontTools/misc/bezierTools.cpython-311-darwin.so
#     - lib/python3.11/site-packages/fontTools/misc/bezierTools.py
#     - lib/python3.11/site-packages/fontTools/misc/classifyTools.py
#     - lib/python3.11/site-packages/fontTools/misc/cliTools.py
#     - lib/python3.11/site-packages/fontTools/misc/configTools.py
#     - lib/python3.11/site-packages/fontTools/misc/cython.py
#     - lib/python3.11/site-packages/fontTools/misc/dictTools.py
#     - lib/python3.11/site-packages/fontTools/misc/eexec.py
#     - lib/python3.11/site-packages/fontTools/misc/encodingTools.py
#     - lib/python3.11/site-packages/fontTools/misc/etree.py
#     - lib/python3.11/site-packages/fontTools/misc/filenames.py
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/__init__.py
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/__pycache__/_base.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/__pycache__/_copy.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/__pycache__/_errors.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/__pycache__/_info.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/__pycache__/_osfs.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/__pycache__/_path.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/__pycache__/_subfs.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/__pycache__/_tempfs.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/__pycache__/_tools.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/__pycache__/_walk.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/__pycache__/_zipfs.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/_base.py
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/_copy.py
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/_errors.py
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/_info.py
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/_osfs.py
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/_path.py
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/_subfs.py
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/_tempfs.py
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/_tools.py
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/_walk.py
#     - lib/python3.11/site-packages/fontTools/misc/filesystem/_zipfs.py
#     - lib/python3.11/site-packages/fontTools/misc/fixedTools.py
#     - lib/python3.11/site-packages/fontTools/misc/intTools.py
#     - lib/python3.11/site-packages/fontTools/misc/iterTools.py
#     - lib/python3.11/site-packages/fontTools/misc/lazyTools.py
#     - lib/python3.11/site-packages/fontTools/misc/loggingTools.py
#     - lib/python3.11/site-packages/fontTools/misc/macCreatorType.py
#     - lib/python3.11/site-packages/fontTools/misc/macRes.py
#     - lib/python3.11/site-packages/fontTools/misc/plistlib/__init__.py
#     - lib/python3.11/site-packages/fontTools/misc/plistlib/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/misc/plistlib/py.typed
#     - lib/python3.11/site-packages/fontTools/misc/psCharStrings.py
#     - lib/python3.11/site-packages/fontTools/misc/psLib.py
#     - lib/python3.11/site-packages/fontTools/misc/psOperators.py
#     - lib/python3.11/site-packages/fontTools/misc/py23.py
#     - lib/python3.11/site-packages/fontTools/misc/roundTools.py
#     - lib/python3.11/site-packages/fontTools/misc/sstruct.py
#     - lib/python3.11/site-packages/fontTools/misc/symfont.py
#     - lib/python3.11/site-packages/fontTools/misc/testTools.py
#     - lib/python3.11/site-packages/fontTools/misc/textTools.py
#     - lib/python3.11/site-packages/fontTools/misc/timeTools.py
#     - lib/python3.11/site-packages/fontTools/misc/transform.py
#     - lib/python3.11/site-packages/fontTools/misc/treeTools.py
#     - lib/python3.11/site-packages/fontTools/misc/vector.py
#     - lib/python3.11/site-packages/fontTools/misc/visitor.py
#     - lib/python3.11/site-packages/fontTools/misc/xmlReader.py
#     - lib/python3.11/site-packages/fontTools/misc/xmlWriter.py
#     - lib/python3.11/site-packages/fontTools/mtiLib/__init__.py
#     - lib/python3.11/site-packages/fontTools/mtiLib/__main__.py
#     - lib/python3.11/site-packages/fontTools/mtiLib/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/mtiLib/__pycache__/__main__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/otlLib/__init__.py
#     - lib/python3.11/site-packages/fontTools/otlLib/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/otlLib/__pycache__/builder.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/otlLib/__pycache__/error.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/otlLib/__pycache__/maxContextCalc.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/otlLib/builder.py
#     - lib/python3.11/site-packages/fontTools/otlLib/error.py
#     - lib/python3.11/site-packages/fontTools/otlLib/maxContextCalc.py
#     - lib/python3.11/site-packages/fontTools/otlLib/optimize/__init__.py
#     - lib/python3.11/site-packages/fontTools/otlLib/optimize/__main__.py
#     - lib/python3.11/site-packages/fontTools/otlLib/optimize/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/otlLib/optimize/__pycache__/__main__.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/otlLib/optimize/__pycache__/gpos.cpython-311.pyc
#     - lib/python3.11/site-packages/fontTools/otlLib/optimize/gpos.py
# ...
#     - lib/python3.11/site-packages/matplotlib/tests/test_arrow_patches.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_artist.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_axes.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_axis.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backend_bases.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backend_cairo.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backend_gtk3.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backend_inline.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backend_macosx.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backend_nbagg.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backend_pdf.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backend_pgf.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backend_ps.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backend_qt.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backend_registry.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backend_svg.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backend_template.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backend_tk.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backend_tools.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backend_webagg.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_backends_interactive.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_basic.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_bbox_tight.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_bezier.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_category.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_cbook.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_collections.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_colorbar.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_colors.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_compare_images.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_constrainedlayout.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_container.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_contour.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_cycles.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_dates.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_datetime.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_determinism.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_doc.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_dviread.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_figure.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_font_manager.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_fontconfig_pattern.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_ft2font.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_getattr.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_gridspec.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_image.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_legend.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_lines.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_marker.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_mathtext.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_matplotlib.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_mlab.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_multivariate_colormaps.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_offsetbox.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_patches.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_path.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_patheffects.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_pickle.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_png.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_polar.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_preprocess_data.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_pyplot.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_quiver.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_rcparams.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_sankey.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_scale.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_simplification.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_skew.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_sphinxext.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_spines.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_streamplot.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_style.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_subplots.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_table.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_testing.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_texmanager.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_text.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_textpath.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_ticker.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_tightlayout.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_transforms.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_triangulation.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_type1font.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_units.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_usetex.py
#     - lib/python3.11/site-packages/matplotlib/tests/test_widgets.py
#     - lib/python3.11/site-packages/matplotlib/texmanager.py
#     - lib/python3.11/site-packages/matplotlib/texmanager.pyi
#     - lib/python3.11/site-packages/matplotlib/text.py
#     - lib/python3.11/site-packages/matplotlib/text.pyi
#     - lib/python3.11/site-packages/matplotlib/textpath.py
#     - lib/python3.11/site-packages/matplotlib/textpath.pyi
#     - lib/python3.11/site-packages/matplotlib/ticker.py
#     - lib/python3.11/site-packages/matplotlib/ticker.pyi
#     - lib/python3.11/site-packages/matplotlib/transforms.py
#     - lib/python3.11/site-packages/matplotlib/transforms.pyi
#     - lib/python3.11/site-packages/matplotlib/tri/__init__.py
#     - lib/python3.11/site-packages/matplotlib/tri/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/matplotlib/tri/__pycache__/_triangulation.cpython-311.pyc
#     - lib/python3.11/site-packages/matplotlib/tri/__pycache__/_tricontour.cpython-311.pyc
#     - lib/python3.11/site-packages/matplotlib/tri/__pycache__/_trifinder.cpython-311.pyc
#     - lib/python3.11/site-packages/matplotlib/tri/__pycache__/_triinterpolate.cpython-311.pyc
#     - lib/python3.11/site-packages/matplotlib/tri/__pycache__/_tripcolor.cpython-311.pyc
#     - lib/python3.11/site-packages/matplotlib/tri/__pycache__/_triplot.cpython-311.pyc
#     - lib/python3.11/site-packages/matplotlib/tri/__pycache__/_trirefine.cpython-311.pyc
#     - lib/python3.11/site-packages/matplotlib/tri/__pycache__/_tritools.cpython-311.pyc
#     - lib/python3.11/site-packages/matplotlib/tri/_triangulation.py
#     - lib/python3.11/site-packages/matplotlib/tri/_triangulation.pyi
#     - lib/python3.11/site-packages/matplotlib/tri/_tricontour.py
#     - lib/python3.11/site-packages/matplotlib/tri/_tricontour.pyi
#     - lib/python3.11/site-packages/matplotlib/tri/_trifinder.py
#     - lib/python3.11/site-packages/matplotlib/tri/_trifinder.pyi
#     - lib/python3.11/site-packages/matplotlib/tri/_triinterpolate.py
#     - lib/python3.11/site-packages/matplotlib/tri/_triinterpolate.pyi
#     - lib/python3.11/site-packages/matplotlib/tri/_tripcolor.py
#     - lib/python3.11/site-packages/matplotlib/tri/_tripcolor.pyi
#     - lib/python3.11/site-packages/matplotlib/tri/_triplot.py
#     - lib/python3.11/site-packages/matplotlib/tri/_triplot.pyi
#     - lib/python3.11/site-packages/matplotlib/tri/_trirefine.py
#     - lib/python3.11/site-packages/matplotlib/tri/_trirefine.pyi
#     - lib/python3.11/site-packages/matplotlib/tri/_tritools.py
#     - lib/python3.11/site-packages/matplotlib/tri/_tritools.pyi
#     - lib/python3.11/site-packages/matplotlib/typing.py
#     - lib/python3.11/site-packages/matplotlib/units.py
#     - lib/python3.11/site-packages/matplotlib/widgets.py
#     - lib/python3.11/site-packages/matplotlib/widgets.pyi
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/__init__.py
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/__pycache__/anchored_artists.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/__pycache__/axes_divider.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/__pycache__/axes_grid.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/__pycache__/axes_rgb.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/__pycache__/axes_size.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/__pycache__/inset_locator.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/__pycache__/mpl_axes.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/__pycache__/parasite_axes.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/anchored_artists.py
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/axes_divider.py
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/axes_grid.py
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/axes_rgb.py
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/axes_size.py
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/inset_locator.py
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/mpl_axes.py
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/parasite_axes.py
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/tests/__init__.py
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/tests/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/tests/__pycache__/conftest.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/tests/__pycache__/test_axes_grid1.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/tests/conftest.py
#     - lib/python3.11/site-packages/mpl_toolkits/axes_grid1/tests/test_axes_grid1.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/__init__.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/__pycache__/angle_helper.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/__pycache__/axes_divider.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/__pycache__/axis_artist.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/__pycache__/axisline_style.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/__pycache__/axislines.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/__pycache__/floating_axes.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/__pycache__/grid_finder.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/__pycache__/grid_helper_curvelinear.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/__pycache__/parasite_axes.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/angle_helper.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/axes_divider.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/axis_artist.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/axisline_style.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/axislines.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/floating_axes.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/grid_finder.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/grid_helper_curvelinear.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/parasite_axes.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/tests/__init__.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/tests/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/tests/__pycache__/conftest.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/tests/__pycache__/test_angle_helper.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/tests/__pycache__/test_axis_artist.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/tests/__pycache__/test_axislines.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/tests/__pycache__/test_floating_axes.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/tests/__pycache__/test_grid_finder.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/tests/__pycache__/test_grid_helper_curvelinear.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/tests/conftest.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/tests/test_angle_helper.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/tests/test_axis_artist.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/tests/test_axislines.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/tests/test_floating_axes.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/tests/test_grid_finder.py
#     - lib/python3.11/site-packages/mpl_toolkits/axisartist/tests/test_grid_helper_curvelinear.py
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/__init__.py
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/__pycache__/art3d.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/__pycache__/axes3d.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/__pycache__/axis3d.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/__pycache__/proj3d.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/art3d.py
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/axes3d.py
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/axis3d.py
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/proj3d.py
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/tests/__init__.py
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/tests/__pycache__/__init__.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/tests/__pycache__/conftest.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/tests/__pycache__/test_art3d.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/tests/__pycache__/test_axes3d.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/tests/__pycache__/test_legend3d.cpython-311.pyc
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/tests/conftest.py
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/tests/test_art3d.py
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/tests/test_axes3d.py
#     - lib/python3.11/site-packages/mpl_toolkits/mplot3d/tests/test_legend3d.py
#     - lib/python3.11/site-packages/pylab.py
# Linking scienceplots-2.1.1-pyhd8ed1ab_1
#
# Transaction finished
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, widgets, VBox, HBox, Layout, Output, Label

import scienceplots
plt.style.use('science')
plt.rcParams['text.usetex'] = False


def softmax_regression_predict(pre_test_probabilities, weights_of_evidence):
    if len(pre_test_probabilities) != len(weights_of_evidence):
        raise ValueError("Lengths of pre_test_probabilities and weights_of_evidence must match.")
    
    # Convert pre-test probabilities to logs; add the log-likelihood ratio
    combined = np.log(pre_test_probabilities) + np.array(weights_of_evidence)
    
    # Softmax for final probabilities
    exp_combined = np.exp(combined - np.max(combined))  # Stability trick
    probabilities = exp_combined / np.sum(exp_combined)
    
    return probabilities


def stacked_chart_pre_post(pre_test_probabilities, post_testing_probabilities, dx_names, weights_of_evidence, figsize=(6, 6)):
    """Visualize the changes in probabilities with dotted lines connecting the top and bottom of pre- and post-test bars."""
    # Check that input lengths match
    if not (len(pre_test_probabilities) == len(post_testing_probabilities) == len(dx_names) == len(weights_of_evidence)):
        raise ValueError("All input arrays must have the same length.")

    # Normalize the probabilities to ensure they sum to 1
    pre_test_probabilities = np.array(pre_test_probabilities) / np.sum(pre_test_probabilities)
    post_testing_probabilities = np.array(post_testing_probabilities) / np.sum(post_testing_probabilities)

    # Combine the data for stacked bar charts
    data = [pre_test_probabilities, post_testing_probabilities]

    # Labels for the x-axis
    x_labels = ["Before Info", "After Info"]

    # Create the plot
    fig, ax = plt.subplots(figsize=figsize)

    # Stacked bar chart
    x = np.arange(len(data))  # Positions for "Before" and "After"
    bottoms = np.zeros(len(data))  # To track stack heights
    width = 0.12  # Increased bar width for better visibility

    # Store top and bottom coordinates for dotted line drawing
    bar_tops = {i: [] for i in range(len(dx_names))}
    bar_bottoms = {i: [] for i in range(len(dx_names))}

    # Add bars and annotate probabilities
    for i, category in enumerate(dx_names):
        values = [data_point[i] for data_point in data]
        bars = ax.bar(x, values, width=width, bottom=bottoms, label=f"{category} (Cumulative LR: {np.exp(weights_of_evidence[i]):.2f})")
        for j, (bar, value) in enumerate(zip(bars, values)):
            # Add text inside each bar
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_y() + bar.get_height() / 2,
                f"{value:.2f}",
                ha="center",
                va="center",
                fontsize=10,
                color="white"
            )
            # Store the top and bottom of each bar
            bar_tops[i].append(bar.get_y() + bar.get_height())
            bar_bottoms[i].append(bar.get_y())

        bottoms += values

    # Add dotted lines connecting the top and bottom of each category
    for i in range(len(dx_names)):
        ax.plot(
            x,  # x-coordinates for "Before" and "After"
            bar_tops[i],  # y-coordinates for the tops of the bars
            linestyle="--", color="gray", alpha=0.5
        )
        ax.plot(
            x,  # x-coordinates for "Before" and "After"
            bar_bottoms[i],  # y-coordinates for the bottoms of the bars
            linestyle="--", color="gray", alpha=0.5
        )

    # Add labels, title, and legend
    ax.set_xticks(x)
    ax.set_xticklabels(x_labels)
    ax.set_ylabel("Probability")
    ax.set_title("Before-Data vs After-Data Probabilities")

    # Move the legend below the chart
    ax.legend(title="Diagnoses", loc="best", bbox_to_anchor=(0.5, -0.15), ncol=1)

    # Adjust layout to avoid overlap
    plt.tight_layout()
    plt.show()


def generalized_predictor_wrapper(diagnoses):
    """
    diagnoses = list of dicts:
    [
      { 'name': <str>, 'pretest': <float from 0 to 1>, 'loglr': <float from -5 to +5> },
      ...
    ]
    """
    pre_test_probs = []
    weights_of_evidence = []
    names = []
    
    for diag in diagnoses:
        names.append(diag['name'])
        pre_test_probs.append(diag['pretest'])
        weights_of_evidence.append(diag['loglr'])

    pre_test_sum = sum(pre_test_probs)
    norm_pre_test_probs = [p / pre_test_sum for p in pre_test_probs]

    predicted_probs = softmax_regression_predict(norm_pre_test_probs, weights_of_evidence) # doesn't need to be norm'd
    
    # Display the results
    print(f"{'Diagnosis':<20}{'Pre-Test Pr':<15}{'Norm. Pre-Test':<15}{'Total LR':<15}{'LogLR':<15}{'Post-Test Pr':<15}")
    print("-" * 95)
    for i, name in enumerate(names):
        print(f"{name:<20}{pre_test_probs[i]:<15.2f}{norm_pre_test_probs[i]:<15.2f}{np.exp(weights_of_evidence[i]):<15.2f}{weights_of_evidence[i]:<15.2f}{predicted_probs[i]:<15.2f}")
    
    return {
        'names': names,
        'pre_test_probs': pre_test_probs,
        'weights_of_evidence': weights_of_evidence,
        'predicted_probs': predicted_probs
    }


def create_diagnosis_widget():
    diagnosis_count = widgets.IntSlider(
        value=1, min=1, max=10, step=1, description="Diagnoses"
    )
    container = VBox()
    chart_output = Output()

    def update_widgets(change):
        if change['name'] == 'value':
            container.children = []
            for i in range(change['new']):
                name_widget = widgets.Text(
                    value=f"Diagnosis {i+1}",
                    description="Name:"
                )
                
                # Pre-test probability slider from 0.0 to 1.0, 2-decimal readout
                pretest_widget = widgets.FloatSlider(
                    value=0.5,
                    min=0.0,
                    max=1.0,
                    step=0.01,
                    description="Pre-Test:",
                    readout_format='.2f'
                )

                # Create the LogLR FloatLogSlider
                loglr_widget = widgets.FloatLogSlider(
                    value=1.0,            # Start with LR = 1
                    base=np.e,            # Base e
                    min=-5.0,             # Minimum LogLR
                    max=5.0,              # Maximum LogLR
                    step=0.1,             # Step size
                    description="Total LR:", # Label for the slider
                    readout=True,
                    readout_format=".2f"
                )

                diagnosis_box = VBox([
                    name_widget,
                    pretest_widget,
                    loglr_widget,
                ])
                container.children += (diagnosis_box,)

    diagnosis_count.observe(update_widgets, names='value')
    
    # Force the initial layout
    update_widgets({'name': 'value', 'new': diagnosis_count.value})

    def gather_inputs(_):
        diagnoses = []
        for diagnosis_box in container.children:
            name = diagnosis_box.children[0].value
            pretest = diagnosis_box.children[1].value
            loglr = np.log(diagnosis_box.children[2].value)  # Transform LR back to LogLR

            diagnoses.append({
                'name': name,
                'pretest': pretest,
                'loglr': loglr
            })

        chart_output.clear_output()
        with chart_output:
            results = generalized_predictor_wrapper(diagnoses)
            stacked_chart_pre_post(
                results['pre_test_probs'],
                results['predicted_probs'],
                results['names'],
                results['weights_of_evidence']
            )

    calculate_button = widgets.Button(description="Calculate")
    calculate_button.on_click(gather_inputs)

    return HBox([VBox([diagnosis_count, container, calculate_button]), chart_output])


# Now create and display the revised widget
diagnosis_widget = create_diagnosis_widget()
display(diagnosis_widget)
# Out:
# HBox(children=(VBox(children=(IntSlider(value=1, description='Diagnoses', max=10, min=1), VBox(children=(VBox(…
